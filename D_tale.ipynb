# %%
import dtale
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
data = pd.read_excel('Clean_data.xlsx')
pd.set_option('display.max_columns',None)
pd.set_option("display.max_rows", None)


d = dtale.show(data)
d.open_browser()
# Out:
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 202, in load_saved_chart
#     return dict(display="block"), charts, config, build_saved_header(config)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 114, in build_saved_header
#     ("Selected Groups", ", ".join(make_list(config["groups"])))
# KeyError: 'groups'
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 202, in load_saved_chart
#     return dict(display="block"), charts, config, build_saved_header(config)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 114, in build_saved_header
#     ("Selected Groups", ", ".join(make_list(config["groups"])))
# KeyError: 'groups'
# 2021-08-21 14:24:47,877 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 202, in load_saved_chart
#     return dict(display="block"), charts, config, build_saved_header(config)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 114, in build_saved_header
#     ("Selected Groups", ", ".join(make_list(config["groups"])))
# KeyError: 'groups'
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 202, in load_saved_chart
#     return dict(display="block"), charts, config, build_saved_header(config)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 114, in build_saved_header
#     ("Selected Groups", ", ".join(make_list(config["groups"])))
# KeyError: 'groups'
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 202, in load_saved_chart
#     return dict(display="block"), charts, config, build_saved_header(config)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 114, in build_saved_header
#     ("Selected Groups", ", ".join(make_list(config["groups"])))
# KeyError: 'groups'
# 2021-08-21 14:25:00,521 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 202, in load_saved_chart
#     return dict(display="block"), charts, config, build_saved_header(config)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/saved_charts.py", line 114, in build_saved_header
#     ("Selected Groups", ", ".join(make_list(config["groups"])))
# KeyError: 'groups'
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2021-08-21 14:25:37,837 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2021-08-21 14:29:28,872 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2021-08-21 14:30:11,329 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2021-08-21 14:33:36,662 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2021-08-21 14:34:07,523 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2021-08-21 14:34:47,156 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2021-08-21 14:38:08,198 - ERROR    - Exception on /dtale/charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1096, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dash/dash.py", line 1017, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/views.py", line 1112, in group_values
#     group_vals = build_group_val_options(group_vals, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/dash_application/layout/layout.py", line 1053, in build_group_val_options
#     group_vals = find_group_vals(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 1000, in find_group_vals
#     group_vals, _ = retrieve_chart_data(df, group_cols)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/dtale/charts/utils.py", line 350, in retrieve_chart_data
#     all_data = pd.concat(all_data, axis=1)
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 274, in concat
#     op = _Concatenator(
#   File "/opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# Executing shutdown due to inactivity...
# Executing shutdown due to inactivity...
# 2021-08-21 15:42:05,133 - INFO     - Executing shutdown due to inactivity...
# Executing shutdown...
# Executing shutdown...
# 2021-08-21 15:42:05,199 - INFO     - Executing shutdown...
